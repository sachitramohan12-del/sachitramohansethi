# %% [markdown]
# <a href="https://colab.research.google.com/github/sachitramohan12-del/sachitramohansethi/blob/main/google_colab_file%203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#access string position
s = "sachi"
print(s[1])
print(s[-1])
print([-2])
# Out:
# a
# i
# [-2]

# %%
#slicing
s = "sachi"
print(s[0:3])
print(s[0:5:2])
print(s[::-1])
# Out:
# sac
# sci
# ihcas

# %%
name = "sachitra"
programming  = "programming"
print(name + programming, sep = "+")
# Out:
# sachitraprogramming

# %%
#search and check
x = "python"
print(x.find("tho"))
print(x.find("red"))
print(x.count("t"))
print(x.startswith("py"))
print(x.endswith("py"))
# Out:
# 2
# -1
# 1
# True
# False

# %%
#string repeatation
a = "*"
print(a*7, sep = "+")
print(a*2)
# Out:
# *******
# **

# %%
#case change
n = "sachi"
print(n.upper())
print(n.lower())
print(n.title())
print(n.swapcase())
# Out:
# SACHI
# sachi
# Sachi
# SACHI

# %%
age = "2"
print(age.isdigit())
print(age.isdigit())
print(age.isalpha())
print(age.isalnum())
# Out:
# True
# True
# False
# True

# %%
name = "  f john   "
print(name)
print(name.strip())
print(name.lstrip())
print(name.rstrip())

print(name.replace("name","age"))


print(name.split())
print(name.split(","))

name2 = "appleis, a fruit and banana is a fruit , fruitis good for health"
print(name2.split(","))
print(name2.split("is"))
# Out:
#   f john
# f john
# f john
#   f john
#   f john
# ['f', 'john']
# ['  f john   ']
# ['appleis', ' a fruit and banana is a fruit ', ' fruitis good for health']
# ['apple', ', a fruit and banana ', ' a fruit , fruit', ' good for health']

# %%
text = "python"
print(text.center(20))
print(text.center(20, "-"))
print(text.ljust(10, "-"))
print(text.rjust(10, "-"))
print(text.zfill(7))
print(text.zfill(20))
# Out:
#        python
# -------python-------
# python----
# ----python
# 0python
# 00000000000000python

# %%
age = 22
# if age > 18 :
#   print("eligible")
#else:
#   print("not")

print("eligible") if age>18 else print("not eligible")
# Out:
# eligible
